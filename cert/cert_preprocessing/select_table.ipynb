# %%
import sqlite3
import pandas as pd

# %%
# SQLite 데이터베이스 연결
conn = sqlite3.connect('./database/database.db')
cursor = conn.cursor()

# TB_meta_info 테이블 조회
# cursor.execute("SELECT * FROM TB_meta_info").fetchall()
# rows = cursor.fetchall()
# cursor.execute("DROP TABLE TB_meta_info;")
# cursor.execute("PRAGMA table_list;").fetchall()

# %%
df = pd.read_sql_query("SELECT * FROM TB_meta_info", conn)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/industry/.venv_industry/lib/python3.10/site-packages/pandas/io/sql.py:2664, in SQLiteDatabase.execute(self, sql, params)
#    2663 try:
# -> 2664     cur.execute(sql, *args)
#    2665     return cur
#
# OperationalError: no such table: TB_meta_info
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df = pd.read_sql_query("SELECT * FROM TB_meta_info", conn)
#
# File ~/industry/.venv_industry/lib/python3.10/site-packages/pandas/io/sql.py:528, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     525 assert dtype_backend is not lib.no_default
#     527 with pandasSQL_builder(con) as pandas_sql:
# --> 528     return pandas_sql.read_query(
#     529         sql,
#     530         index_col=index_col,
#     531         params=params,
#     532         coerce_float=coerce_float,
#     533         parse_dates=parse_dates,
#     534         chunksize=chunksize,
#     535         dtype=dtype,
#     536         dtype_backend=dtype_backend,
#     537     )
#
# File ~/industry/.venv_industry/lib/python3.10/site-packages/pandas/io/sql.py:2728, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2717 def read_query(
#    2718     self,
#    2719     sql,
#    (...)
#    2726     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2727 ) -> DataFrame | Iterator[DataFrame]:
# -> 2728     cursor = self.execute(sql, params)
#    2729     columns = [col_desc[0] for col_desc in cursor.description]
#    2731     if chunksize is not None:
#
# File ~/industry/.venv_industry/lib/python3.10/site-packages/pandas/io/sql.py:2676, in SQLiteDatabase.execute(self, sql, params)
#    2673     raise ex from inner_exc
#    2675 ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2676 raise ex from exc
#
# DatabaseError: Execution failed on sql 'SELECT * FROM TB_meta_info': no such table: TB_meta_info

# %%
df = pd.read_sql_query("SELECT * FROM TB_meta_info", conn)

# %%
df
# Out:
#                                                  full_path  \
# 0        /mnt/external_drive/industry_data/cctv_data/da...
# 1        /mnt/external_drive/industry_data/cctv_data/da...
# 2        /mnt/external_drive/industry_data/cctv_data/da...
# 3        /mnt/external_drive/industry_data/cctv_data/da...
# 4        /mnt/external_drive/industry_data/cctv_data/da...
# ...                                                    ...
# 2757107  /mnt/external_drive/industry_data/sand_data/da...
# 2757108  /mnt/external_drive/industry_data/sand_data/da...
# 2757109  /mnt/external_drive/industry_data/sand_data/da...
# 2757110  /mnt/external_drive/industry_data/sand_data/da...
# 2757111  /mnt/external_drive/industry_data/sand_data/da...
#
#                                       file_id    folder_name  file_size  \
# 0        bde2a668-197d-40b6-9e69-926e64ec125e     label_data   16281009
# 1        9de4ae95-f224-482b-9245-4213c7a73f40     label_data   20319814
# 2        a8912032-fa9b-449a-82d2-7a0c95894d3a     label_data   18182020
# 3        b27e684a-bd31-4fca-97a4-70905aafc2ba     label_data   16194919
# 4        01b63eb6-6c56-46d7-8a09-a0894d08e8e5     label_data   14802585
# ...                                       ...            ...        ...
# 2757107  d697d69b-35b6-4b84-a65f-ecc40f9ac58c  VS_2.모래위험광물분류    5862592
# 2757108  6ccd6229-312f-4db3-9f40-4e35be470884  VS_2.모래위험광물분류    5373272
# 2757109  fc1031d6-650f-42c5-a175-11f6124181ad  VS_2.모래위험광물분류    5439086
# 2757110  8f276abd-5e63-414d-a26f-48037114ea37      02.라벨링데이터   28313802
# 2757111  134f2360-0aa7-4712-9d35-0c78b6bcddbc      02.라벨링데이터  149955891
#
#         file_size_readable file_type data_category
# 0                  15.5 MB      .zip     cctv_data
# 1                  19.4 MB      .zip     cctv_data
# 2                  17.3 MB      .zip     cctv_data
# 3                  15.4 MB      .zip     cctv_data
# 4                  14.1 MB      .zip     cctv_data
# ...                    ...       ...           ...
# 2757107             5.6 MB      .png     sand_data
# 2757108             5.1 MB      .png     sand_data
# 2757109             5.2 MB      .png     sand_data
# 2757110            27.0 MB      .zip     sand_data
# 2757111           143.0 MB      .zip     sand_data
#
# [2757112 rows x 7 columns]

# %%
conn.close()
